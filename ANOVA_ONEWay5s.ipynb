# %% [markdown]
# Hãy sử dụng các tập dữ liệu sau và tiến hành phân tích ANOVA 1 chiều
#
# - [Excavation Depth and Archaeology](https://college.cengage.com/mathematics/brase/understandable_statistics/7e/students/datasets/owan/frames/owan01.html)
# - [Apple Orchard Experiment](https://college.cengage.com/mathematics/brase/understandable_statistics/7e/students/datasets/owan/frames/owan02.html)
# - [Red Dye Number 40](https://college.cengage.com/mathematics/brase/understandable_statistics/7e/students/datasets/owan/frames/owan03.html)
# - [Business Startup Costs](https://college.cengage.com/mathematics/brase/understandable_statistics/7e/students/datasets/owan/frames/owan04.html)
# - [Weights of Football Players](https://college.cengage.com/mathematics/brase/understandable_statistics/7e/students/datasets/owan/frames/owan05.html)

# %%
#Thư vieenjn và hàm
import pandas as pd
import seaborn as sns # For Data Visualization
from scipy.stats import norm # for scientific Computing
import matplotlib.pyplot as plt # For Data Visualization
import statsmodels.api as sm
import numpy as np
from scipy import stats
from scipy.stats import kstest
from scipy.stats import f_oneway


def hist(inp):
    plt.figure()
    ax = sns.distplot(inp)
    plt.axvline(np.mean(inp), color="r", linestyle="dashed", linewidth=5)
    _, max_ = plt.ylim()
    plt.text(
        inp.mean() + inp.mean() / 10,
        max_ - max_ / 10,
        "Mean: {:.2f}".format(inp.mean()),
    )
    return plt.figure

# %% [markdown]
# QUY TRÌNH PHÂN TÍCH ANOVA MỘT CHIỀU
#
# Kiểm tra các giả định:
#
#  - Các mẫu độc lập với nhau
#  - Các mẫu có cùng phương sai
#  - Các mẫu đều tuân theo phân phối chuẩn

# %%
#File owan1 có kích thước các series khác nhau.
print('Bởi kích thước của các series là khác nhau nên chúng ta không thể phân tích anova 1 chiều với file owan1.csv')
# Out:
# Bởi kích thước của các series là khác nhau nên chúng ta không thể phân tích anova 1 chiều với file owan1.csv

# %%
#File owan2
# Biểu đồ
data2 = pd.read_csv('owan02.csv')
print(data2.head())

st1, p1 = stats.shapiro(data2['X1'])
st2, p2 = stats.shapiro(data2['X2'])
st3, p3 = stats.shapiro(data2["X3"])
st4, p4 = stats.shapiro(data2["X4"])
st5, p5 = stats.shapiro(data2["X5"])
# Out:
#      X1    X2    X3    X4    X5
# 0  2569  2074  2505  2838  1532
# 1  2928  2885  2315  2351  2552
# 2  2865  3378  2667  3001  3083
# 3  3844  3906  2390  2439  2330
# 4  3027  2782  3021  2199  2079

# %%
hist(data2['X1'])
plt.title('Graph of X1')
#qq
da1 = (data2['X1'] - data2['X1'].mean()) /data2['X1'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X1 = ',st1)
print('pvalue of X1 = ',p1)
if (p1 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X1 =  0.9433721303939819
# pvalue of X1 =  0.644533634185791
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data2['X2'])
plt.title('Graph of X2')
#qq
da2 = (data2['X2'] - data2['X2'].mean()) /data2['X2'].std()
sm.qqplot(da2, line='45')
plt.show()

print('statistic of X2 = ',st2)
print('pvalue of X2 = ',p2)
if (p2 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X2 =  nan
# pvalue of X2 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data2['X3'])
plt.title('Graph of X3')
#qq
da1 = (data2['X3'] - data2['X3'].mean()) /data2['X3'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X3 = ',st3)
print('pvalue of X3 = ',p3)
if (p3 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X3 =  0.9045020341873169
# pvalue of X3 =  0.3169650137424469
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data2['X4'])
plt.title('Graph of X4')
#qq
da1 = (data2['X4'] - data2['X4'].mean()) /data2['X4'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X3 = ',st4)
print('pvalue of X3 = ',p4)
if (p4 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X3 =  0.9388160705566406
# pvalue of X3 =  0.5994704365730286
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data2['X5'])
plt.title('Graph of X5')
plt.show
#qq
da1 = (data2['X5'] - data2['X5'].mean()) /data2['X5'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X3 = ',st5)
print('pvalue of X3 = ',p5)
if (p5 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X3 =  0.9593089818954468
# pvalue of X3 =  0.803491473197937
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
#Code kiểm định tính đồng nhất về phương sai của các nhóm

st13, p13 = stats.bartlett(data2['X1'], data2['X2'], data2['X3'], data2['X4'], data2['X5'])
print('statistic by Bartlett = ',st13)
print('pvalue by Bartlett = ',p13)
if (p13 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là các dữ liệu đồng nhất')
else:
    print('Đấy không phải là các dữ liệu đồng nhất')
print('-'*50)
# Out:
# statistic by Bartlett =  1.505379741017298
# pvalue by Bartlett =  0.825688088344803
# Không đủ bằng chứng để bác bỏ: Đây là các dữ liệu đồng nhất
# --------------------------------------------------

# %%
#kiểm định anova 1 chiều
statistic,pvalue = f_oneway(data2['X1'], data2['X2'], data2['X3'], data2['X4'], data2['X5'])
print("Kiểm định anova 1 chiều: \n statistic = ",statistic,"\n pvalue = ",pvalue)
if pvalue < 0.05:
    print('reject H0')
else:
      print('can not reject H0')
# Out:
# Kiểm định anova 1 chiều:
#  statistic =  1.3142198672637213
#  pvalue =  0.28382583646160114
# can not reject H0

# %%
#File owan03,owan04 có kích thước các series khác nhau
print('Bởi kích thước của các series là khác nhau nên chúng ta không thể phân tích anova 1 chiều với file owan1.csv')

# %%
#owan05
data5 = pd.read_csv('owan05.csv')
print(data5.head())


st1, p1 = stats.shapiro(data5['X1'])
st2, p2 = stats.shapiro(data5['X2'])
st3, p3 = stats.shapiro(data5["X3"])
st4, p4 = stats.shapiro(data5["X4"])
st5, p5 = stats.shapiro(data5["X5"])
# Out:
#     X1   X2   X3   X4   X5
# 0  250  260  270  260  247
# 1  255  271  250  255  249
# 2  255  258  281  265  255
# 3  264  263  273  257  247
# 4  250  267  257  268  244

# %%
hist(data5['X1'])
plt.title('Graph of X1')
#qq
da1 = (data5['X1'] - data5['X1'].mean()) /data5['X1'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X1 = ',st1)
print('pvalue of X1 = ',p1)
if (p1 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X1 =  0.8771048784255981
# pvalue of X1 =  0.028549334034323692
# Đấy không phải dữ liệu phân phối chuẩn

# %%
hist(data5['X2'])
plt.title('Graph of X2')
#qq
da1 = (data5['X2'] - data5['X2'].mean()) /data5['X2'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X2 = ',st2)
print('pvalue of X2 = ',p2)
if (p2 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X2 =  0.9226022958755493
# pvalue of X2 =  0.16341625154018402
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data5['X3'])
plt.title('Graph of X3')
#qq
da1 = (data5['X3'] - data5['X3'].mean()) /data5['X3'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X3 = ',st3)
print('pvalue of X3 = ',p3)
if (p3 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X3 =  0.9616518616676331
# pvalue of X3 =  0.6627115607261658
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data5['X4'])
plt.title('Graph of X4')
#qq
da1 = (data5['X4'] - data5['X4'].mean()) /data5['X4'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X4 = ',st4)
print('pvalue of X4 = ',p4)
if (p4 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X4 =  0.8918235898017883
# pvalue of X4 =  0.0496593713760376
# Đấy không phải dữ liệu phân phối chuẩn

# %%
hist(data5['X5'])
plt.title('Graph of X5')
#qq
da1 = (data5['X5'] - data5['X5'].mean()) /data5['X5'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X5 = ',st5)
print('pvalue of X5 = ',p5)
if (p5 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X5 =  0.9416549205780029
# pvalue of X5 =  0.3383376896381378
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
#Code kiểm định tính đồng nhất về phương sai của các nhóm
print("Bởi đây có dữ liệu ko tuân theo phân phối chuẩn nên ta dùng kiểm định levene về kiểm định tính đống nhất của Phương sai")
st44, p44 = stats.levene(data5['X1'], data5['X2'], data5['X3'], data5['X4'], data5['X5'])
print('statistic by levene = ',st44)
print('pvalue by levene = ',p4)
if (p4 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là các dữ liệu đồng nhất')
else:
    print('Đấy không phải là các dữ liệu đồng nhất')
print('-'*50)
# Out:
# Bởi đây có dữ liệu ko tuân theo phân phối chuẩn nên ta dùng kiểm định levene về kiểm định tính đống nhất của Phương sai
# statistic by levene =  0.09184463103914253
# pvalue by levene =  0.0496593713760376
# Đấy không phải là các dữ liệu đồng nhất
# --------------------------------------------------

# %%
#kiểm định anova 1 chiều
statistic,pvalue = f_oneway(data5['X1'], data5['X2'], data5['X3'], data5['X4'], data5['X5'])
print("Kiểm định anova 1 chiều: \n statistic = ",statistic,"\n pvalue = ",pvalue)
if pvalue < 0.05:
    print('reject H0')
else:
      print('can not reject H0')
# Out:
# Kiểm định anova 1 chiều:
#  statistic =  1.5772240916480775
#  pvalue =  0.18840454722696476
# can not reject H0

# %%
print('Đối với các dataframe với các series kích thước không bằng nhau như owan01, owan03, owan02')
# Out:
# Đối với các dataframe với các series kích thước không bằng nhau như owan01, owan03, owan02

# %%
#File owan1
# Biểu đồ
data1 = pd.read_csv('owan01.csv')
print(data1.head())

st1, p1 = stats.shapiro(data1['X1'])
st2, p2 = stats.shapiro(data1['X2'])
st3, p3 = stats.shapiro(data1["X3"])
st4, p4 = stats.shapiro(data1["X4"])
# Out:
#     X1    X2     X3    X4
# 0   93  85.0  100.0  96.0
# 1  120  45.0   75.0  58.0
# 2   65  80.0   65.0  95.0
# 3  105  28.0   40.0  90.0
# 4  115  75.0   73.0  65.0

# %%
hist(data1['X1'])
plt.title('Graph of X1')
#qq
da1 = (data1['X1'] - data1['X1'].mean()) /data1['X1'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X1 = ',st1)
print('pvalue of X1 = ',p1)
if (p1 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X1 =  0.9865291118621826
# pvalue of X1 =  0.9960364103317261
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data1['X2'])
plt.title('Graph of X2')
#qq
da1 = (data1['X2'] - data1['X2'].mean()) /data1['X2'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X2 = ',st2)
print('pvalue of X2 = ',p2)
if (p2 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')

# %%
hist(data1['X3'])
plt.title('Graph of X3')
#qq
da1 = (data1['X3'] - data1['X3'].mean()) /data1['X3'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X3 = ',st3)
print('pvalue of X3 = ',p3)
if (p3 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X1 =  nan
# pvalue of X1 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data1['X4'])
plt.title('Graph of X4')
#qq
da1 = (data1['X4'] - data1['X4'].mean()) /data1['X4'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X4 = ',st4)
print('pvalue of X4 = ',p4)
if (p4 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X4 =  nan
# pvalue of X4 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
#Code kiểm định tính đồng nhất về phương sai của các nhóm

st13, p13 = stats.bartlett(data1['X1'], data1['X2'], data1['X3'], data1['X4'])
print('statistic by Bartlett = ',st13)
print('pvalue by Bartlett = ',p13)
if (p13 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là các dữ liệu đồng nhất')
else:
    print('Đấy không phải là các dữ liệu đồng nhất')
print('-'*50)
# Out:
# statistic by Bartlett =  2.440153553631599
# pvalue by Bartlett =  0.48620382137845997
# Không đủ bằng chứng để bác bỏ: Đây là các dữ liệu đồng nhất
# --------------------------------------------------

# %%
#kiểm định anova 1 chiều
#Bởi đây là dataframe có các series không cùng size mẫu nên không thể kiểm định anova 
statistic,pvalue = f_oneway(data1['X1'], data1['X2'], data1['X3'], data1['X4'])
print("Kiểm định anova 1 chiều: \n statistic = ",statistic,"\n pvalue = ",pvalue)
if pvalue < 0.05:
    print('reject H0')
else:
      print('can not reject H0')
# Out:
# Kiểm định anova 1 chiều:
#  statistic =  nan
#  pvalue =  nan
# can not reject H0

# %%
#File owan3
# Biểu đồ
data3 = pd.read_csv('owan03.csv')
print(data1.head())

st1, p1 = stats.shapiro(data3['X1'])
st2, p2 = stats.shapiro(data3['X2'])
st3, p3 = stats.shapiro(data3["X3"])
st4, p4 = stats.shapiro(data3["X4"])
# Out:
#     X1    X2     X3    X4
# 0   93  85.0  100.0  96.0
# 1  120  45.0   75.0  58.0
# 2   65  80.0   65.0  95.0
# 3  105  28.0   40.0  90.0
# 4  115  75.0   73.0  65.0

# %%
hist(data3['X1'])
plt.title('Graph of X1')
#qq
da1 = (data3['X1'] - data3['X1'].mean()) /data3['X1'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X1 = ',st1)
print('pvalue of X1 = ',p1)
if (p1 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X1 =  0.9092681407928467
# pvalue of X1 =  0.23906797170639038
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data3['X2'])
plt.title('Graph of X2')
#qq
da1 = (data3['X2'] - data3['X2'].mean()) /data3['X2'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X2 = ',st2)
print('pvalue of X2 = ',p2)
if (p2 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X2 =  nan
# pvalue of X2 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data3['X3'])
plt.title('Graph of X3')
#qq
da1 = (data3['X3'] - data3['X3'].mean()) /data3['X3'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X3 = ',st3)
print('pvalue of X3 = ',p3)
if (p3 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X3 =  nan
# pvalue of X3 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data3['X4'])
plt.title('Graph of X4')
#qq
da1 = (data3['X4'] - data3['X4'].mean()) /data3['X4'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X4 = ',st4)
print('pvalue of X4 = ',p4)
if (p4 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X4 =  nan
# pvalue of X4 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
#Code kiểm định tính đồng nhất về phương sai của các nhóm
#Nếu dữ liệu của các series là phân phối chuẩn thì sử dụng Bartlett còn không thì sử dụng levene

st33, p33 = stats.bartlett(data3['X1'], data3['X2'], data3['X3'], data3['X4'])
print('statistic by Bartlett = ',st33)
print('pvalue by Bartlett = ',p33)
if (p33 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là các dữ liệu đồng nhất')
else:
    print('Đấy không phải là các dữ liệu đồng nhất nên không thể kiểm định ANOVA một chiều')
print('-'*50)
# Out:
# statistic by Bartlett =  12.022305190389242
# pvalue by Bartlett =  0.007307141609688417
# Đấy không phải là các dữ liệu đồng nhất
# --------------------------------------------------

# %%
#kiểm định anova 1 chiều

#Bởi đây là dataframe có các series không cùng size mẫu nên không thể kiểm định anova 
statistic,pvalue = f_oneway(data3['X1'], data3['X2'], data3['X3'], data3['X4'])
print("Kiểm định anova 1 chiều: \n statistic = ",statistic,"\n pvalue = ",pvalue)
if pvalue < 0.05:
    print('reject H0')
else:
      print('can not reject H0')
# Out:
# Kiểm định anova 1 chiều:
#  statistic =  nan
#  pvalue =  nan
# can not reject H0

# %%
#File owan4
# Biểu đồ
data4 = pd.read_csv('owan04.csv')
print(data2.head())

st1, p1 = stats.shapiro(data4['X1'])
st2, p2 = stats.shapiro(data4['X2'])
st3, p3 = stats.shapiro(data4["X3"])
st4, p4 = stats.shapiro(data4["X4"])
st5, p5 = stats.shapiro(data4["X5"])
# Out:
#      X1    X2    X3    X4    X5
# 0  2569  2074  2505  2838  1532
# 1  2928  2885  2315  2351  2552
# 2  2865  3378  2667  3001  3083
# 3  3844  3906  2390  2439  2330
# 4  3027  2782  3021  2199  2079

# %%
hist(data4['X1'])
plt.title('Graph of X1')
#qq
da1 = (data4['X1'] - data4['X1'].mean()) /data4['X1'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X1 = ',st1)
print('pvalue of X1 = ',p1)
if (p1 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X1 =  nan
# pvalue of X1 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data4['X2'])
plt.title('Graph of X2')
#qq
da1 = (data4['X2'] - data4['X2'].mean()) /data4['X2'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X2 = ',st2)
print('pvalue of X2 = ',p2)
if (p2 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X2 =  nan
# pvalue of X2 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data4['X3'])
plt.title('Graph of X3')
#qq
da1 = (data4['X3'] - data4['X3'].mean()) /data4['X3'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X3 = ',st3)
print('pvalue of X3 = ',p3)
if (p3 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X3 =  nan
# pvalue of X3 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data4['X4'])
plt.title('Graph of X4')
#qq
da1 = (data4['X4'] - data4['X4'].mean()) /data4['X4'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X4 = ',st4)
print('pvalue of X4 = ',p4)
if (p4 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X4 =  nan
# pvalue of X4 =  1.0
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
hist(data4['X5'])
plt.title('Graph of X5')
#qq
da1 = (data4['X5'] - data4['X5'].mean()) /data4['X5'].std()
sm.qqplot(da1, line='45')
plt.show()

print('statistic of X5 = ',st5)
print('pvalue of X5 = ',p5)
if (p5 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn')
else:
    print('Đấy không phải dữ liệu phân phối chuẩn')
# Out:
# statistic of X5 =  0.9208388924598694
# pvalue of X5 =  0.17400741577148438
# Không đủ bằng chứng để bác bỏ: Đây là dữ liệu phân phối chuẩn

# %%
#Code kiểm định tính đồng nhất về phương sai của các nhóm
#Nếu dữ liệu của các series là phân phối chuẩn thì sử dụng Bartlett còn không thì sử dụng levene

st44, p44 = stats.bartlett(data4['X1'], data4['X2'], data4['X3'], data4['X4'], data4['X5'])
print('statistic by Bartlett = ',st44)
print('pvalue by Bartlett = ',p44)
if (p44 > 0.05):
    print('Không đủ bằng chứng để bác bỏ: Đây là các dữ liệu đồng nhất')
else:
    print('Đấy không phải là các dữ liệu đồng nhất nên không thể kiểm định ANOVA một chiều')
print('-'*50)
# Out:
# statistic by Bartlett =  2.149120392490446
# pvalue by Bartlett =  0.7083542065575461
# Không đủ bằng chứng để bác bỏ: Đây là các dữ liệu đồng nhất
# --------------------------------------------------

# %%
#kiểm định anova 1 chiều
#Bởi đây là dataframe có các series không cùng size mẫu nên không thể kiểm định anova 


statistic,pvalue = f_oneway(data4['X1'], data4['X2'], data4['X3'], data4['X4'], data4['X5'])
print("Kiểm định anova 1 chiều: \n statistic = ",statistic,"\n pvalue = ",pvalue)
if pvalue < 0.05:
    print('reject H0')
else:
      print('can not reject H0')
# Out:
# Kiểm định anova 1 chiều:
#  statistic =  nan
#  pvalue =  nan
# can not reject H0
